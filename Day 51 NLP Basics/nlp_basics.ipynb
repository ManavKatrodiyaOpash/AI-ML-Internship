# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import ne_chunk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
text = "AI is very powerful and I love learning it."
text = "Elon Musk founded Tesla in California and I really love AI."

# %%
tokens = word_tokenize(text)

tokens
# Out:
# ['Elon',
#  'Musk',
#  'founded',
#  'Tesla',
#  'in',
#  'California',
#  'and',
#  'I',
#  'really',
#  'love',
#  'AI',
#  '.']

# %%
stop_words = set(stopwords.words('english'))

filtered_words = [word for word in tokens if word.lower() not in stop_words]

filtered_words
# Out:
# ['Elon', 'Musk', 'founded', 'Tesla', 'California', 'really', 'love', 'AI', '.']

# %%
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_words]

stemmed_words
# Out:
# ['elon', 'musk', 'found', 'tesla', 'california', 'realli', 'love', 'ai', '.']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

lemmatized_words
# Out:
# ['Elon', 'Musk', 'founded', 'Tesla', 'California', 'really', 'love', 'AI', '.']

# %%
pos_tags = nltk.pos_tag(tokens)

pos_tags
# Out:
# [('Elon', 'NNP'),
#  ('Musk', 'NNP'),
#  ('founded', 'VBD'),
#  ('Tesla', 'NNP'),
#  ('in', 'IN'),
#  ('California', 'NNP'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('really', 'RB'),
#  ('love', 'VB'),
#  ('AI', 'NNP'),
#  ('.', '.')]

# %%
ner = ne_chunk(pos_tags)

ner
# Out:
# Tree('S', [Tree('PERSON', [('Elon', 'NNP')]), Tree('PERSON', [('Musk', 'NNP')]), ('founded', 'VBD'), Tree('PERSON', [('Tesla', 'NNP')]), ('in', 'IN'), Tree('GPE', [('California', 'NNP')]), ('and', 'CC'), ('I', 'PRP'), ('really', 'RB'), ('love', 'VB'), ('AI', 'NNP'), ('.', '.')])
