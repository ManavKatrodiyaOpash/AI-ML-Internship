# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error
from sklearn.tree import plot_tree

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#      Area_sqft  Bedrooms  Bathrooms  House_Age  Distance_City_km  Price_Lakhs
# 0         1360         1          2         16                36    18.250141
# 1         1794         4          2         29                 9    53.657573
# 2         1630         5          2          9                27    61.340832
# 3         1595         1          3         10                34    18.467258
# 4         2138         1          2         21                 1    71.268595
# ..         ...       ...        ...        ...               ...          ...
# 995       1375         3          1          2                27    31.096919
# 996       1262         4          2         11                12    50.356478
# 997       1702         5          3         12                 1    83.974084
# 998       1705         2          1         12                11    57.197816
# 999       1163         3          1          9                39    23.405218
#
# [1000 rows x 6 columns]

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = DecisionTreeRegressor(
    random_state=42,
    max_depth=5
)

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 169.4870436986863

# %%
root_mean_squared_error(y_test, y_pred)
# Out:
# 13.018718973028273

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7572900797208197

# %%
model.predict([[1800,3,2,5,3]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([74.67711031])

# %%
plt.rcParams['figure.figsize'] = (70, 50)
tree = plot_tree(
    model,
    feature_names=x.columns,
    filled=True,
    rounded=True,
    fontsize=50
)
plt.savefig("decision_tree.png",dpi=100)
plt.tight_layout()
plt.show()
