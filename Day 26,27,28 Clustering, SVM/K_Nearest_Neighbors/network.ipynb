# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df = pd.read_csv("Social_Network_Ads.csv")

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])

# %%
x = df[['Gender','Age','EstimatedSalary']]
y = df['Purchased']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.825

# %%
scores = []
train_test_score = []

for i in range(1,16):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    y_pred = knn.predict(x_test)
    scores.append(accuracy_score(y_test, y_pred))

    train_score = knn.score(x_train, y_train)
    test_score = knn.score(x_test, y_test)

    print(f"K = {i} :- ")
    print(f"\tTrain_score = {train_score} :- ")
    print(f"\tTest_score = {test_score} :- ")
    print(f"\tAccuracy Score = {accuracy_score(y_test, y_pred)} :- ")
    print("-"*50)

    train_test_score.append({
        "K" : i,
        "Train_score" : train_score,
        "Test_score" : test_score,
        "Accuracy Score" : accuracy_score(y_test, y_pred)
    })
df_train_test_score = pd.DataFrame(train_test_score)
# Out:
# K = 1 :-
# 	Train_score = 0.996875 :-
# 	Test_score = 0.8125 :-
# 	Accuracy Score = 0.8125 :-
# --------------------------------------------------
# K = 2 :-
# 	Train_score = 0.878125 :-
# 	Test_score = 0.7625 :-
# 	Accuracy Score = 0.7625 :-
# --------------------------------------------------
# K = 3 :-
# 	Train_score = 0.9 :-
# 	Test_score = 0.8 :-
# 	Accuracy Score = 0.8 :-
# --------------------------------------------------
# K = 4 :-
# 	Train_score = 0.8625 :-
# 	Test_score = 0.8 :-
# 	Accuracy Score = 0.8 :-
# --------------------------------------------------
# K = 5 :-
# 	Train_score = 0.88125 :-
# 	Test_score = 0.825 :-
# 	Accuracy Score = 0.825 :-
# --------------------------------------------------
# K = 6 :-
# 	Train_score = 0.85 :-
# 	Test_score = 0.775 :-
# 	Accuracy Score = 0.775 :-
# --------------------------------------------------
# K = 7 :-
# 	Train_score = 0.865625 :-
# 	Test_score = 0.8125 :-
# 	Accuracy Score = 0.8125 :-
# --------------------------------------------------
# K = 8 :-
# 	Train_score = 0.85 :-
# 	Test_score = 0.775 :-
# 	Accuracy Score = 0.775 :-
# --------------------------------------------------
# K = 9 :-
# 	Train_score = 0.85 :-
# 	Test_score = 0.8 :-
# 	Accuracy Score = 0.8 :-
# --------------------------------------------------
# K = 10 :-
# 	Train_score = 0.83125 :-
# 	Test_score = 0.775 :-
# 	Accuracy Score = 0.775 :-
# --------------------------------------------------
# K = 11 :-
# 	Train_score = 0.84375 :-
# 	Test_score = 0.8 :-
# 	Accuracy Score = 0.8 :-
# --------------------------------------------------
# K = 12 :-
# 	Train_score = 0.825 :-
# 	Test_score = 0.775 :-
# 	Accuracy Score = 0.775 :-
# --------------------------------------------------
# K = 13 :-
# 	Train_score = 0.828125 :-
# 	Test_score = 0.75 :-
# 	Accuracy Score = 0.75 :-
# --------------------------------------------------
# K = 14 :-
# 	Train_score = 0.815625 :-
# 	Test_score = 0.7625 :-
# 	Accuracy Score = 0.7625 :-
# --------------------------------------------------
# K = 15 :-
# 	Train_score = 0.828125 :-
# 	Test_score = 0.775 :-
# 	Accuracy Score = 0.775 :-
# --------------------------------------------------

# %%
plt.plot(range(1, 16), scores)
plt.tight_layout()
plt.show()

# %%
df_train_test_score
# Out:
#      K  Train_score  Test_score  Accuracy Score
# 0    1     0.996875      0.8125          0.8125
# 1    2     0.878125      0.7625          0.7625
# 2    3     0.900000      0.8000          0.8000
# 3    4     0.862500      0.8000          0.8000
# 4    5     0.881250      0.8250          0.8250
# 5    6     0.850000      0.7750          0.7750
# 6    7     0.865625      0.8125          0.8125
# 7    8     0.850000      0.7750          0.7750
# 8    9     0.850000      0.8000          0.8000
# 9   10     0.831250      0.7750          0.7750
# 10  11     0.843750      0.8000          0.8000
# 11  12     0.825000      0.7750          0.7750
# 12  13     0.828125      0.7500          0.7500
# 13  14     0.815625      0.7625          0.7625
# 14  15     0.828125      0.7750          0.7750

# %% [markdown]
# *Number of cluster is 5 best here
