# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
x,y = load_iris(return_X_y=True)

# %%
log_model = LogisticRegression(max_iter=200)
tr_model = DecisionTreeClassifier()
knn = KNeighborsClassifier()

# %%
models = {
    "LogisticRegression": log_model,
    "DecisionTreeClassifier": tr_model,
    "KNeighborsClassifier": knn
}

cv_lst = [3, 5, 10]

# %%
for model in models:
    for cv in cv_lst:
        score = cross_val_score(models[model], x, y, cv=cv)
        print(f"{model} |  CV : {cv} | CV score Mean: {np.mean(score)}")
# Out:
# LogisticRegression |  CV : 3 | CV score Mean: 0.9733333333333333
# LogisticRegression |  CV : 5 | CV score Mean: 0.9733333333333334
# LogisticRegression |  CV : 10 | CV score Mean: 0.9733333333333334
# DecisionTreeClassifier |  CV : 3 | CV score Mean: 0.96
# DecisionTreeClassifier |  CV : 5 | CV score Mean: 0.9666666666666668
# DecisionTreeClassifier |  CV : 10 | CV score Mean: 0.9533333333333334
# KNeighborsClassifier |  CV : 3 | CV score Mean: 0.98
# KNeighborsClassifier |  CV : 5 | CV score Mean: 0.9733333333333334
# KNeighborsClassifier |  CV : 10 | CV score Mean: 0.9666666666666668
