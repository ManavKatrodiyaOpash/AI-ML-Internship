# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
x, y = load_wine(return_X_y=True)

# %%
x_scaled = StandardScaler().fit_transform(x)

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

# %%
km_og = KMeans(n_clusters=3, random_state=42)
labels_og = km_og.fit_predict(x_scaled)

# %%
km_pca = KMeans(n_clusters=3, random_state=42)
labels_pca = km_pca.fit_predict(x_pca)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,6))

ax1.scatter(x[:,0], x[:,1], c=labels_og)
ax1.set_title("KMeans before PCA")
ax1.set_xlabel("x")
ax1.set_ylabel("y")

ax2.scatter(x_pca[:,0], x_pca[:,1], c=labels_pca)
ax2.set_title("KMeans after PCA")
ax2.set_xlabel("x")
ax2.set_ylabel("y")

plt.tight_layout()
plt.show()

# %%
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
print("Total Variance:", pca.explained_variance_ratio_.sum())
# Out:
# Explained Variance Ratio: [0.36198848 0.1920749 ]
# Total Variance: 0.5540633835693526
