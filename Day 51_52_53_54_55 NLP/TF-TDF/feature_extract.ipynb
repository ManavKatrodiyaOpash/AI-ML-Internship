# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                   text  output
# 0  people watch marvel       1
# 1      people watch dc       1
# 2    people write code       0
# 3       i watch marvel       1

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()
cv2 = CountVectorizer(ngram_range=(2,2))
cv12 = CountVectorizer(ngram_range=(1,2))

# %%
bow = cv.fit_transform(df['text'])
bow2 = cv2.fit_transform(df['text'])
bow12 = cv12.fit_transform(df['text'])

# %%
print(cv.vocabulary_)
print(cv2.vocabulary_)
print(cv12.vocabulary_)
# Out:
# {'people': 3, 'watch': 4, 'marvel': 2, 'dc': 1, 'write': 5, 'code': 0}
# {'people watch': 0, 'watch marvel': 3, 'watch dc': 2, 'people write': 1, 'write code': 4}
# {'people': 3, 'watch': 6, 'marvel': 2, 'people watch': 4, 'watch marvel': 8, 'dc': 1, 'watch dc': 7, 'write': 9, 'code': 0, 'people write': 5, 'write code': 10}
