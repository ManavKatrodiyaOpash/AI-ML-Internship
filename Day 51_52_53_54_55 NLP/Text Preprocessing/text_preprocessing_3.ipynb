# %%
import pandas as pd

# %%
df = pd.read_csv("top_rated_movies.csv")

# %%
df
# Out:
#       adult                     backdrop_path        genre_ids     id  \
# 0     False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]    278
# 1     False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg         [18, 80]    238
# 2     False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]    240
# 3     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]    424
# 4     False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg             [18]    389
# ...     ...                               ...              ...    ...
# 9415  False  /l2zqOzP0HVdH6Reor96b0nGlKxp.jpg    [28, 12, 878]   9562
# 9416  False  /8nluZo04z9Y8iynYmnMmvO9bU9L.jpg       [27, 9648]  10053
# 9417  False  /lePVhFlkuRsE24agMApfg1V4wrB.jpg      [35, 10749]  15681
# 9418  False  /ifOEPOHMnoT9YRu8dcvf26HsW47.jpg     [35, 80, 28]  10723
# 9419  False  /1MllG91Hzn5cgmN4uFn0Jg2D0i6.jpg       [27, 9648]   9877
#
#      original_language            original_title  \
# 0                   en  The Shawshank Redemption
# ...

# %%
df[["title", "overview"]]
# Out:
#                          title  \
# 0     The Shawshank Redemption
# 1                The Godfather
# 2        The Godfather Part II
# 3             Schindler's List
# 4                 12 Angry Men
# ...                        ...
# 9415                  Timeline
# 9416     When a Stranger Calls
# 9417                        Ex
# 9418               Bulletproof
# 9419              Urban Legend
#
#                                                overview
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9415  A group of archaeological students become trap...
# 9416  Far away from the site of a gruesome murder, a...
# 9417  Six people struggling with their relationship,...
# ...

# %%
df["overview"].isnull().sum()
# Out:
# np.int64(2)

# %%
df.dropna(inplace=True)

# %%
from text_preprocessing_pipeline import preprocess_text

df["clean_overview"] = df["overview"].apply(preprocess_text)

# %%
df[["title", "overview", "clean_overview"]]
# Out:
#                          title  \
# 0     The Shawshank Redemption
# 1                The Godfather
# 2        The Godfather Part II
# 3             Schindler's List
# 4                 12 Angry Men
# ...                        ...
# 9415                  Timeline
# 9416     When a Stranger Calls
# 9417                        Ex
# 9418               Bulletproof
# 9419              Urban Legend
#
#                                                overview  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9415  A group of archaeological students become trap...
# 9416  Far away from the site of a gruesome murder, a...
# 9417  Six people struggling with their relationship,...
# ...
