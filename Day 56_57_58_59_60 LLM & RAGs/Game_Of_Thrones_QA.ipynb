—his principal lords and bannermen,
—SER HELMAN TALLHART,
—RICKARD KARSTARK, Lord of Karhold,
—ROOSE BOLTON, Lord of the Dreadfort,
—JON UMBER, called the Greatjon,
—GALBART AND ROBETT GLOVER,
—WYMAN MANDERLY, Lord of White Harbor,
—MAEGE MORMONT, the Lady of Bear Island,
The principal houses sworn to Winterfell are Karstark, Umber, Flint,
Mormont, Hornwood, Cerwyn, Reed, Manderly, Glover, Tallhart, Bolton
"""

# %%
def split_text(text, chunk_size=300):
    words = text.split()
    chunks = []

    for i in range(0, len(words), chunk_size):
        chunks.append(" ".join(words[i:i+chunk_size]))

    return chunks

prologue_chunks = split_text(prologue_text)
baratheon_chunks = split_text(baratheon_text)
stark_chunks = split_text(stark_text)

print("Total Prologue Text chunks :-", len(prologue_chunks))
print("Total Baratheon Text chunks :-", len(baratheon_chunks))
print("Total Stark Text chunks :-", len(stark_chunks))
# Out:
# Total Prologue Text chunks :- 13
# Total Baratheon Text chunks :- 2
# Total Stark Text chunks :- 2

# %%
def get_answer_pro(question):
    best_answer = ""
    best_score = 0

    for chunk in prologue_chunks:
        result = question_answerer(question=question, context=chunk)

        if result['score'] > best_score:
            best_score = result['score']
            best_answer = result['answer']

    return best_answer, best_score

def get_answer_br(question):
    best_answer = ""
    best_score = 0

    for chunk in baratheon_chunks:
        result = question_answerer(question=question, context=chunk)

        if result['score'] > best_score:
            best_score = result['score']
            best_answer = result['answer']

    return best_answer, best_score

def get_answer_st(question):
    best_answer = ""
    best_score = 0

    for chunk in stark_chunks:
        result = question_answerer(question=question, context=chunk)

        if result['score'] > best_score:
            best_score = result['score']
            best_answer = result['answer']

    return best_answer, best_score

# %%
prologue_questions = ["Who is Ser Waymar Royce?",
             "What is the age of Ser Waymar Royce ?",
             "Who was hunter before joining Night's Watch ?",
             "Whose mother said that dead men sing no song ?",
             "How many wildlings will saw that are dead ?",
             "Who ask will about details ?",
             "What is the age of Gared ?",
             "How many Years Gared spent in the Night's Watch ?",
             "Who saw them dead ?",
             "What did the wet nurse said ?",
             "did the wet nurse said the same thing ?",
             "How many Years Will spent on the Night's Watch ?"]

for question in prologue_questions:
  answer, score = get_answer_pro(question)

  print("Question :-", question)
  print("Answer:-", answer)
  print("Confidence:-", score)
  print("\n")
# Out:
# Question :- Who is Ser Waymar Royce?
# Answer:- lordling
# Confidence:- 1.3024851423688233
#
#
# Question :- What is the age of Ser Waymar Royce ?
# Answer:- A boy
# Confidence:- 0.8355542421340942
#
#
# Question :- Who was hunter before joining Night's Watch ?
# Answer:- Will
# Confidence:- 0.3953403360210359
#
#
# Question :- Whose mother said that dead men sing no song ?
# Answer:- Ser Waymar Royce
# Confidence:- 0.19714778661727905
#
#
# Question :- How many wildlings will saw that are dead ?
# Answer:- Will saw them
# Confidence:- 0.6220888495445251
#
#
# Question :- Who ask will about details ?
# Answer:- Royce
# Confidence:- 0.14468784863129258
#
#
# Question :- What is the age of Gared ?
# Answer:- old man, past fifty
# Confidence:- 0.22446857392787933
#
#
# Question :- How many Years Gared spent in the Night's Watch ?
# Answer:- forty
# Confidence:- 0.9573159217834473
#
#
# Question :- Who saw them dead ?
# Answer:- Will saw them
# Confidence:- 0.6350170373916626
#
#
# ...

# %%
baratheon_questions = ["who is the king ?",
                       "Who is the lord of storm's end ?",
                       "Who is the lord commander of the kingsguard ?",
                       "what are the words of house baratheon ?",
                       "who is the lord of dragonstone ?",
                       "who is the QUEEN ?",
                       "who is the wife of robert ?",
                       "Who is the KING ?",
                       "Who is the heir of iron throne ?",
                       "who is called as the kingslayer ?"]

for question in baratheon_questions:
  answer, score = get_answer_br(question)

  print("Question :-", question)
  print("Answer:-", answer)
  print("Confidence:-", score)
  print("\n")
# Out:
# Question :- who is the king ?
# Answer:- KING ROBERT BARATHEON, the First of His Name
# Confidence:- 0.7014822363853455
#
#
# Question :- Who is the lord of storm's end ?
# Answer:- RENLY BARATHEON, Lord of Storm’s End
# Confidence:- 0.6809923052787781
#
#
# Question :- Who is the lord commander of the kingsguard ?
# Answer:- SER BARRISTAN SELMY
# Confidence:- 1.1160397096537054
#
#
# Question :- what are the words of house baratheon ?
# Answer:- Ours is the Fury
# Confidence:- 0.6352095687252586
#
#
# Question :- who is the lord of dragonstone ?
# Answer:- STANNIS BARATHEON
# Confidence:- 0.5573590585263446
#
#
# Question :- who is the QUEEN ?
# Answer:- QUEEN CERSEI, of House Lannister
# Confidence:- 0.4732755990116857
#
#
# Question :- who is the wife of robert ?
# Answer:- QUEEN CERSEI, of House Lannister
# Confidence:- 0.5545960874296725
#
#
# Question :- Who is the KING ?
# Answer:- KING ROBERT BARATHEON, the First of His Name
# Confidence:- 0.6082335710525513
#
#
# ...

# %%
stark_questions = ["who is the lord of winterfell ?",
             "who is the wife of eddard stark ?",
             "which house did LADY CATELYN belong to ?",
             "who is the heir of winterfell ?",
             "what is the age of ROBB ?",
             "what is the age of SANSA ?",
             "what is the age of ARYA ?",
             "what is the age of BRANDON ?",
             "what is the age of RICKON ?",
             "who is the basterd son of eddard stark ?",
             "who is the heir of iron islands ?",
             "who are the his principal lords and bannermen of house stark ?",
             "who are the siblings of eddard stark ?",
             "how many siblings eddard stark has ?",
             "What are The principal houses sworn to Winterfell ?"]

for question in stark_questions:
  answer, score = get_answer_st(question)

  print("Question :-", question)
  print("Answer:-", answer)
  print("Confidence:-", score)
  print("\n")
# Out:
# Question :- who is the lord of winterfell ?
# Answer:- EDDARD STARK, Lord of Winterfell
# Confidence:- 0.8114140183024574
#
#
# Question :- who is the wife of eddard stark ?
# Answer:- LADY CATELYN, of House Tully
# Confidence:- 0.45057666883803904
#
#
# Question :- which house did LADY CATELYN belong to ?
# Answer:- House Tully
# Confidence:- 0.8247618675231934
#
#
# Question :- who is the heir of winterfell ?
# Answer:- ROBB, the heir to Winterfell, fourteen years of age
# Confidence:- 0.4700987935066223
#
#
# Question :- what is the age of ROBB ?
# Answer:- fourteen years of age
# Confidence:- 0.8577611446380615
#
#
# Question :- what is the age of SANSA ?
# Answer:- eleven
# Confidence:- 0.8178619742393494
#
#
# Question :- what is the age of ARYA ?
# Answer:- nine
# Confidence:- 0.0028839618898928165
#
#
# Question :- what is the age of BRANDON ?
# Answer:- seven
# Confidence:- 0.47683632373809814
#
#
# Question :- what is the age of RICKON ?
# Answer:- three
# ...
