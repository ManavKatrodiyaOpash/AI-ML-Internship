# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading and Seeing the Dataset

# %%
df = pd.read_csv("messy_customer_data.csv")

# %%
df
# Out:
#      Customer_ID    Age  Gender  Annual_Income  Spending_Score    City  \
# 0              1   50.0    Male        50000.0             NaN  Mumbai
# 1              2   35.0     NaN        50000.0            10.0     NaN
# 2              3    NaN    Male        20000.0            50.0     NaN
# 3              4   40.0    Male       999999.0             NaN   Delhi
# 4              5   50.0     NaN        70000.0            50.0     NaN
# ..           ...    ...     ...            ...             ...     ...
# 495          496   18.0    male        50000.0           120.0     NaN
# 496          497   50.0       M        50000.0           120.0    Pune
# 497          498   50.0    Male       999999.0            10.0     NaN
# 498          499  150.0  Female        70000.0           120.0    Pune
# 499          500   30.0       F            NaN            40.0   Delhi
#
#     Purchased
# 0           N
# 1         Yes
# 2          No
# 3          No
# 4         NaN
# ..        ...
# 495        No
# 496         Y
# 497         Y
# 498       Yes
# 499       NaN
#
# [500 rows x 7 columns]

# %%
df.shape
# Out:
# (500, 7)

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Annual_Income', 'Spending_Score',
#        'City', 'Purchased'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Customer_ID         Age  Annual_Income  Spending_Score
# count   500.000000  449.000000     414.000000      426.000000
# mean    250.500000   40.815145  231110.913043       43.333333
# std     144.481833   39.360390  382943.116516       34.568488
# min       1.000000   -5.000000   20000.000000       10.000000
# 25%     125.750000   18.000000   30000.000000       20.000000
# 50%     250.500000   35.000000   50000.000000       30.000000
# 75%     375.250000   45.000000   70000.000000       50.000000
# max     500.000000  150.000000  999999.000000      120.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Customer_ID         int64
# Age               float64
# Gender             object
# Annual_Income     float64
# Spending_Score    float64
# City               object
# Purchased          object
# dtype: object

# %% [markdown]
# # Handling Missing Values

# %%
df
# Out:
#      Customer_ID    Age  Gender  Annual_Income  Spending_Score    City  \
# 0              1   50.0    Male        50000.0             NaN  Mumbai
# 1              2   35.0     NaN        50000.0            10.0     NaN
# 2              3    NaN    Male        20000.0            50.0     NaN
# 3              4   40.0    Male       999999.0             NaN   Delhi
# 4              5   50.0     NaN        70000.0            50.0     NaN
# ..           ...    ...     ...            ...             ...     ...
# 495          496   18.0    male        50000.0           120.0     NaN
# 496          497   50.0       M        50000.0           120.0    Pune
# 497          498   50.0    Male       999999.0            10.0     NaN
# 498          499  150.0  Female        70000.0           120.0    Pune
# 499          500   30.0       F            NaN            40.0   Delhi
#
#     Purchased
# 0           N
# 1         Yes
# 2          No
# 3          No
# 4         NaN
# ..        ...
# 495        No
# 496         Y
# 497         Y
# 498       Yes
# 499       NaN
#
# [500 rows x 7 columns]

# %% [markdown]
# ## Converting empty string to NAN

# %%
cat_cols = df.select_dtypes(include="object").columns
cat_cols
# Out:
# Index(['Gender', 'City', 'Purchased'], dtype='object')

# %%
df[cat_cols] = df[cat_cols].replace("", np.nan)

print("Empty strings converted to NaN")
# Out:
# Empty strings converted to NaN

# %%
print(df[cat_cols].isnull().sum())
# Out:
# Gender        86
# City         168
# Purchased    110
# dtype: int64

# %% [markdown]
# ## Handling Age Column

# %%
df['Age']
# Out:
# 0       50.0
# 1       35.0
# 2        NaN
# 3       40.0
# 4       50.0
#        ...
# 495     18.0
# 496     50.0
# 497     50.0
# 498    150.0
# 499     30.0
# Name: Age, Length: 500, dtype: float64

# %%
df['Age'].value_counts()
# Out:
# Age
#  18.0     62
#  30.0     57
#  50.0     55
# -5.0      54
#  40.0     49
#  35.0     48
#  150.0    44
#  25.0     41
#  45.0     39
# Name: count, dtype: int64

# %%
df['Age'] = df['Age'].mask((df['Age'] < 0) | (df['Age'] > 100), np.nan)

# %%
df['Age'].value_counts()
# Out:
# Age
# 18.0    62
# 30.0    57
# 50.0    55
# 40.0    49
# 35.0    48
# 25.0    41
# 45.0    39
# Name: count, dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df['Age']
# Out:
# 0      50.0
# 1      35.0
# 2      35.0
# 3      40.0
# 4      50.0
#        ...
# 495    18.0
# 496    50.0
# 497    50.0
# 498    35.0
# 499    30.0
# Name: Age, Length: 500, dtype: float64

# %% [markdown]
# ## Handling Gender Column

# %%
df['Gender']
# Out:
# 0        Male
# 1         NaN
# 2        Male
# 3        Male
# 4         NaN
#         ...
# 495      male
# 496         M
# 497      Male
# 498    Female
# 499         F
# Name: Gender, Length: 500, dtype: object

# %%
df['Gender'].value_counts()
# Out:
# Gender
# male      90
# Male      88
# Female    81
# F         78
# M         77
# Name: count, dtype: int64

# %%
df['Gender'].replace({
    'M': "Male",
    "male": "Male",
    'F': "Female",
    np.nan: "unknown"
}, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       255
# Female     159
# unknown     86
# Name: count, dtype: int64

# %%
df['Gender']
# Out:
# 0         Male
# 1      unknown
# 2         Male
# 3         Male
# 4      unknown
#         ...
# 495       Male
# 496       Male
# 497       Male
# 498     Female
# 499     Female
# Name: Gender, Length: 500, dtype: object

# %% [markdown]
# ## Handling Annual_Income column

# %%
df['Annual_Income']
# Out:
# 0       50000.0
# 1       50000.0
# 2       20000.0
# 3      999999.0
# 4       70000.0
#          ...
# 495     50000.0
# 496     50000.0
# 497    999999.0
# 498     70000.0
# 499         NaN
# Name: Annual_Income, Length: 500, dtype: float64

# %%
df['Annual_Income'].value_counts()
# Out:
# Annual_Income
# 50000.0     91
# 20000.0     86
# 30000.0     86
# 999999.0    82
# 70000.0     69
# Name: count, dtype: int64

# %%
df['Annual_Income'].fillna(df['Annual_Income'].median(), inplace=True)

# %%
df['Annual_Income']
# Out:
# 0       50000.0
# 1       50000.0
# 2       20000.0
# 3      999999.0
# 4       70000.0
#          ...
# 495     50000.0
# 496     50000.0
# 497    999999.0
# 498     70000.0
# 499     50000.0
# Name: Annual_Income, Length: 500, dtype: float64

# %% [markdown]
# ## Handling Spending_Score Column

# %%
df['Spending_Score']
# Out:
# 0        NaN
# 1       10.0
# 2       50.0
# 3        NaN
# 4       50.0
#        ...
# 495    120.0
# 496    120.0
# 497     10.0
# 498    120.0
# 499     40.0
# Name: Spending_Score, Length: 500, dtype: float64

# %%
df['Spending_Score'].isnull().sum()
# Out:
# np.int64(74)

# %%
df['Spending_Score'].value_counts()
# Out:
# Spending_Score
# 10.0     74
# 50.0     74
# 30.0     74
# 40.0     71
# 20.0     70
# 120.0    63
# Name: count, dtype: int64

# %%
df['Spending_Score'].fillna(df['Spending_Score'].median(), inplace=True)

# %% [markdown]
# ## Handling City Column

# %%
df['City']
# Out:
# 0      Mumbai
# 1         NaN
# 2         NaN
# 3       Delhi
# 4         NaN
#         ...
# 495       NaN
# 496      Pune
# 497       NaN
# 498      Pune
# 499     Delhi
# Name: City, Length: 500, dtype: object

# %%
df['City'].value_counts()
# Out:
# City
# Pune         94
# Delhi        91
# Mumbai       83
# Ahmedabad    64
# Name: count, dtype: int64

# %%
df['City'].replace({
    np.nan: "unknown",
}, inplace=True)

# %%
df['City'].value_counts()
# Out:
# City
# unknown      168
# Pune          94
# Delhi         91
# Mumbai        83
# Ahmedabad     64
# Name: count, dtype: int64

# %% [markdown]
# ## Handling Purchased Score

# %%
df['Purchased']
# Out:
# 0        N
# 1      Yes
# 2       No
# 3       No
# 4      NaN
#       ...
# 495     No
# 496      Y
# 497      Y
# 498    Yes
# 499    NaN
# Name: Purchased, Length: 500, dtype: object

# %%
df['Purchased'].replace({
    np.nan: "unknown",
    "Y": "Yes",
    "N": "No",
}, inplace=True)

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# No         210
# Yes        180
# unknown    110
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# Customer_ID  Age   Gender   Annual_Income  Spending_Score  City     Purchased
# 1            50.0  Male     50000.0        30.0            Mumbai   No           1
# 2            35.0  unknown  50000.0        10.0            unknown  Yes          1
# 3            35.0  Male     20000.0        50.0            unknown  No           1
# 4            40.0  Male     999999.0       30.0            Delhi    No           1
# 5            50.0  unknown  70000.0        50.0            unknown  unknown      1
#                                                                                 ..
# 496          18.0  Male     50000.0        120.0           unknown  No           1
# 497          50.0  Male     50000.0        120.0           Pune     Yes          1
# 498          50.0  Male     999999.0       10.0            unknown  Yes          1
# 499          35.0  Female   70000.0        120.0           Pune     Yes          1
# 500          30.0  Female   50000.0        40.0            Delhi    unknown      1
# Name: count, Length: 500, dtype: int64

# %%
df.to_csv("cleaned_data.csv",index=False)

# %% [markdown]
# # Hanndling with Outliers using visualization

# %%
df
# Out:
#      Customer_ID   Age   Gender  Annual_Income  Spending_Score     City  \
# 0              1  50.0     Male        50000.0            30.0   Mumbai
# 1              2  35.0  unknown        50000.0            10.0  unknown
# 2              3  35.0     Male        20000.0            50.0  unknown
# 3              4  40.0     Male       999999.0            30.0    Delhi
# 4              5  50.0  unknown        70000.0            50.0  unknown
# ..           ...   ...      ...            ...             ...      ...
# 495          496  18.0     Male        50000.0           120.0  unknown
# 496          497  50.0     Male        50000.0           120.0     Pune
# 497          498  50.0     Male       999999.0            10.0  unknown
# 498          499  35.0   Female        70000.0           120.0     Pune
# 499          500  30.0   Female        50000.0            40.0    Delhi
#
#     Purchased
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4     unknown
# ..        ...
# 495        No
# 496       Yes
# 497       Yes
# 498       Yes
# 499   unknown
#
# [500 rows x 7 columns]

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns
cat_cols = df.select_dtypes(include="object").columns

# %%
num_cols
# Out:
# Index(['Customer_ID', 'Age', 'Annual_Income', 'Spending_Score'], dtype='object')

# %%
cat_cols
# Out:
# Index(['Gender', 'City', 'Purchased'], dtype='object')

# %% [markdown]
# ## Ploting to see outliers

# %%
plt.style.use("default")  # reset dark theme issues
sns.set_theme(style="whitegrid")

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["figure.dpi"] = 120

# %%
for col in num_cols:
    plt.boxplot(df[col])
    plt.title(f"Boxplot of {col}")
    plt.tight_layout()
    plt.show()

# %%
for col in num_cols:
    df[col].plot(kind="kde")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Removing Outliers if detected

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}: {outliers.shape[0]} outliers detected")
# Out:
# Customer_ID: 0 outliers detected
# Age: 0 outliers detected
# Annual_Income: 82 outliers detected
# Spending_Score: 63 outliers detected

# %%
# =====================================
# OPTION C: Remove outliers
# =====================================

for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]

print("Outliers removed")
# Out:
# Outliers removed

# %% [markdown]
# ## Ploting after removing outliers

# %%
for col in num_cols:
    plt.boxplot(df[col])
    plt.title(f"Boxplot of {col}")
    plt.tight_layout()
    plt.show()

# %%
for col in num_cols:
    df[col].plot(kind="kde")
    plt.tight_layout()
    plt.show()

# %%
sns.scatterplot(
    x=df["Age"],
    y=df["Spending_Score"]
)
plt.title("Age vs Spending Score")
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(
    x=df["Annual_Income"],
    y=df["Spending_Score"]
)
plt.title("Income vs Spending Score")
plt.show()

# %%
sns.boxplot(
    x=df["Gender"],
    y=df["Spending_Score"]
)
plt.title("Gender vs Spending Score")
plt.tight_layout()
plt.show()

# %%
df.to_csv("cleaned_dataset_without_outlier.csv",index=False)

# %% [markdown]
# # Feature Enginerring

# %%
df
# Out:
#      Customer_ID   Age   Gender  Annual_Income  Spending_Score       City  \
# 0              1  50.0     Male        50000.0            30.0     Mumbai
# 1              2  35.0  unknown        50000.0            10.0    unknown
# 2              3  35.0     Male        20000.0            50.0    unknown
# 4              5  50.0  unknown        70000.0            50.0    unknown
# 5              6  35.0   Female        50000.0            40.0       Pune
# ..           ...   ...      ...            ...             ...        ...
# 491          492  50.0   Female        50000.0            30.0    unknown
# 492          493  35.0   Female        50000.0            50.0  Ahmedabad
# 493          494  50.0   Female        50000.0            50.0    unknown
# 494          495  40.0  unknown        30000.0            30.0  Ahmedabad
# 499          500  30.0   Female        50000.0            40.0      Delhi
#
#     Purchased
# 0          No
# 1         Yes
# 2          No
# 4     unknown
# 5         Yes
# ..        ...
# 491   unknown
# 492        No
# 493        No
# 494       Yes
# 499   unknown
#
# [364 rows x 7 columns]

# %% [markdown]
# ## Making a AgeGroup column

# %%
df["Age_Group"] = pd.cut(
    df["Age"],
    bins=[0, 25, 35, 50, 100],
    labels=["Young", "Adult", "Middle_Aged", "Senior"]
)

# %%
df["Age_Group"].value_counts()
# Out:
# Age_Group
# Adult          191
# Middle_Aged     94
# Young           79
# Senior           0
# Name: count, dtype: int64

# %% [markdown]
# ## Making Gender numerical

# %%
df['Gender_Binary'] = (df['Gender'])

df['Gender_Binary'].replace({
    "Male" : 1,
    "Female" : 0,
    "unknown" : -1
},inplace=True)

# %%
df['Gender_Binary']
# Out:
# 0      1
# 1     -1
# 2      1
# 4     -1
# 5      0
#       ..
# 491    0
# 492    0
# 493    0
# 494   -1
# 499    0
# Name: Gender_Binary, Length: 364, dtype: int64

# %% [markdown]
# ## Making cateogry for Annual_Income

# %%
df['Annual_Income'].value_counts()
# Out:
# Annual_Income
# 50000.0    157
# 30000.0     77
# 20000.0     71
# 70000.0     59
# Name: count, dtype: int64

# %%
df['Income_Bracket'] = pd.cut(
    df['Annual_Income'],
    bins=[0, 30000, 60000, 1000000],
    labels=["Low","Medium","High"]
)

# %%
df['Income_Bracket']
# Out:
# 0      Medium
# 1      Medium
# 2         Low
# 4        High
# 5      Medium
#         ...
# 491    Medium
# 492    Medium
# 493    Medium
# 494       Low
# 499    Medium
# Name: Income_Bracket, Length: 364, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %% [markdown]
# ## Income Ratio Column

# %%
df["Spend_Income_Ratio"] = df["Spending_Score"] / df["Annual_Income"]
df["Spend_Income_Ratio"].describe()
# Out:
# count    364.000000
# mean       0.000846
# std        0.000548
# min        0.000143
# 25%        0.000429
# 50%        0.000667
# 75%        0.001000
# max        0.002500
# Name: Spend_Income_Ratio, dtype: float64

# %% [markdown]
# ## Visualizing some plots

# %%
sns.boxplot(x=df["Age_Group"], y=df["Spending_Score"])
plt.title("Spending Score by Age Group")
plt.tight_layout()
plt.show()

# %%
df
# Out:
#      Customer_ID   Age  Gender  Annual_Income  Spending_Score       City  \
# 0              1  50.0       1        50000.0            30.0     Mumbai
# 1              2  35.0      -1        50000.0            10.0    unknown
# 2              3  35.0       1        20000.0            50.0    unknown
# 4              5  50.0      -1        70000.0            50.0    unknown
# 5              6  35.0       0        50000.0            40.0       Pune
# ..           ...   ...     ...            ...             ...        ...
# 491          492  50.0       0        50000.0            30.0    unknown
# 492          493  35.0       0        50000.0            50.0  Ahmedabad
# 493          494  50.0       0        50000.0            50.0    unknown
# 494          495  40.0      -1        30000.0            30.0  Ahmedabad
# 499          500  30.0       0        50000.0            40.0      Delhi
#
#     Purchased    Age_Group  Gender_Binary Income_Bracket  Spend_Income_Ratio
# 0          No  Middle_Aged              1         Medium            0.000600
# 1         Yes        Adult             -1         Medium            0.000200
# 2          No        Adult              1            Low            0.002500
# 4     unknown  Middle_Aged             -1           High            0.000714
# 5         Yes        Adult              0         Medium            0.000800
# ..        ...          ...            ...            ...                 ...
# 491   unknown  Middle_Aged              0         Medium            0.000600
# 492        No        Adult              0         Medium            0.001000
# 493        No  Middle_Aged              0         Medium            0.001000
# 494       Yes  Middle_Aged             -1            Low            0.001000
# 499   unknown        Adult              0         Medium            0.000800
#
# [364 rows x 11 columns]
