# %%
import optuna
import pandas as pd

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
           'DiabetesPedigreeFunction', 'Age', 'Outcome']
df = pd.read_csv(url, names=columns)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df.drop("Outcome", axis=1)
y = df["Outcome"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
def objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 50, 200)
    max_depth = trial.suggest_int("max_depth", 3, 10)

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=42
    )

    score = cross_val_score(model, x_train, y_train, scoring="accuracy").mean()

    return score

# %%
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler())
study.optimize(objective, n_trials=50)
# Out:
# [I 2026-02-03 17:25:09,628] A new study created in memory with name: no-name-d47b05f0-78ee-410c-b4db-3f38ca484304
# [I 2026-02-03 17:25:10,895] Trial 0 finished with value: 0.7687458349993337 and parameters: {'n_estimators': 144, 'max_depth': 7}. Best is trial 0 with value: 0.7687458349993337.
# [I 2026-02-03 17:25:11,697] Trial 1 finished with value: 0.760629081700653 and parameters: {'n_estimators': 96, 'max_depth': 4}. Best is trial 0 with value: 0.7687458349993337.
# [I 2026-02-03 17:25:13,357] Trial 2 finished with value: 0.7736372117819539 and parameters: {'n_estimators': 196, 'max_depth': 7}. Best is trial 2 with value: 0.7736372117819539.
# [I 2026-02-03 17:25:14,160] Trial 3 finished with value: 0.7622550979608156 and parameters: {'n_estimators': 92, 'max_depth': 9}. Best is trial 2 with value: 0.7736372117819539.
# [I 2026-02-03 17:25:15,343] Trial 4 finished with value: 0.7606157536985206 and parameters: {'n_estimators': 160, 'max_depth': 3}. Best is trial 2 with value: 0.7736372117819539.
# [I 2026-02-03 17:25:16,889] Trial 5 finished with value: 0.7703985072637611 and parameters: {'n_estimators': 194, 'max_depth': 5}. Best is trial 2 with value: 0.7736372117819539.
# [I 2026-02-03 17:25:17,560] Trial 6 finished with value: 0.7769159003065441 and parameters: {'n_estimators': 78, 'max_depth': 7}. Best is trial 6 with value: 0.7769159003065441.
# [I 2026-02-03 17:25:18,551] Trial 7 finished with value: 0.7590030654404905 and parameters: {'n_estimators': 115, 'max_depth': 9}. Best is trial 6 with value: 0.7769159003065441.
# [I 2026-02-03 17:25:19,876] Trial 8 finished with value: 0.7671331467413035 and parameters: {'n_estimators': 157, 'max_depth': 10}. Best is trial 6 with value: 0.7769159003065441.
# [I 2026-02-03 17:25:20,634] Trial 9 finished with value: 0.7719978675196588 and parameters: {'n_estimators': 91, 'max_depth': 5}. Best is trial 6 with value: 0.7769159003065441.
# [I 2026-02-03 17:25:21,119] Trial 10 finished with value: 0.7703985072637611 and parameters: {'n_estimators': 54, 'max_depth': 8}. Best is trial 6 with value: 0.7769159003065441.
# [I 2026-02-03 17:25:22,684] Trial 11 finished with value: 0.7703985072637611 and parameters: {'n_estimators': 193, 'max_depth': 6}. Best is trial 6 with value: 0.7769159003065441.
# [I 2026-02-03 17:25:23,167] Trial 12 finished with value: 0.7801546048247368 and parameters: {'n_estimators': 52, 'max_depth': 7}. Best is trial 12 with value: 0.7801546048247368.
# [I 2026-02-03 17:25:23,608] Trial 13 finished with value: 0.7606957217113155 and parameters: {'n_estimators': 52, 'max_depth': 6}. Best is trial 12 with value: 0.7801546048247368.
# [I 2026-02-03 17:25:24,225] Trial 14 finished with value: 0.7687858190057311 and parameters: {'n_estimators': 72, 'max_depth': 8}. Best is trial 12 with value: 0.7801546048247368.
# [I 2026-02-03 17:25:24,871] Trial 15 finished with value: 0.7704118352658936 and parameters: {'n_estimators': 71, 'max_depth': 8}. Best is trial 12 with value: 0.7801546048247368.
# [I 2026-02-03 17:25:26,130] Trial 16 finished with value: 0.7703851792616287 and parameters: {'n_estimators': 116, 'max_depth': 5}. Best is trial 12 with value: 0.7801546048247368.
# [I 2026-02-03 17:25:26,750] Trial 17 finished with value: 0.7801812608290019 and parameters: {'n_estimators': 72, 'max_depth': 7}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:27,213] Trial 18 finished with value: 0.7606957217113155 and parameters: {'n_estimators': 53, 'max_depth': 6}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:27,983] Trial 19 finished with value: 0.7703985072637611 and parameters: {'n_estimators': 69, 'max_depth': 9}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:28,893] Trial 20 finished with value: 0.7671331467413035 and parameters: {'n_estimators': 102, 'max_depth': 10}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:29,744] Trial 21 finished with value: 0.7785419165667067 and parameters: {'n_estimators': 79, 'max_depth': 7}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:30,677] Trial 22 finished with value: 0.7785419165667067 and parameters: {'n_estimators': 79, 'max_depth': 7}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:31,331] Trial 23 finished with value: 0.7720378515260562 and parameters: {'n_estimators': 65, 'max_depth': 8}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:32,119] Trial 24 finished with value: 0.7671864587498334 and parameters: {'n_estimators': 83, 'max_depth': 6}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:33,045] Trial 25 finished with value: 0.7719845395175264 and parameters: {'n_estimators': 106, 'max_depth': 7}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:33,572] Trial 26 finished with value: 0.7720111955217913 and parameters: {'n_estimators': 60, 'max_depth': 8}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:34,694] Trial 27 finished with value: 0.7687458349993337 and parameters: {'n_estimators': 141, 'max_depth': 5}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:35,388] Trial 28 finished with value: 0.7671864587498334 and parameters: {'n_estimators': 85, 'max_depth': 6}. Best is trial 17 with value: 0.7801812608290019.
# [I 2026-02-03 17:25:35,932] Trial 29 finished with value: 0.786658669865387 and parameters: {'n_estimators': 61, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:36,990] Trial 30 finished with value: 0.7557243769159003 and parameters: {'n_estimators': 133, 'max_depth': 4}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:37,527] Trial 31 finished with value: 0.7850326536052246 and parameters: {'n_estimators': 62, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:38,072] Trial 32 finished with value: 0.783406637345062 and parameters: {'n_estimators': 64, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:38,593] Trial 33 finished with value: 0.7850326536052246 and parameters: {'n_estimators': 62, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:39,190] Trial 34 finished with value: 0.7703851792616286 and parameters: {'n_estimators': 62, 'max_depth': 8}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:39,701] Trial 35 finished with value: 0.7623084099693457 and parameters: {'n_estimators': 61, 'max_depth': 6}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:40,505] Trial 36 finished with value: 0.7638811142209783 and parameters: {'n_estimators': 94, 'max_depth': 9}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:41,250] Trial 37 finished with value: 0.7769025723044115 and parameters: {'n_estimators': 88, 'max_depth': 8}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:42,087] Trial 38 finished with value: 0.7752499000399841 and parameters: {'n_estimators': 101, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:42,591] Trial 39 finished with value: 0.7590030654404905 and parameters: {'n_estimators': 60, 'max_depth': 4}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:43,990] Trial 40 finished with value: 0.760629081700653 and parameters: {'n_estimators': 182, 'max_depth': 3}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:44,607] Trial 41 finished with value: 0.7769025723044116 and parameters: {'n_estimators': 73, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:45,170] Trial 42 finished with value: 0.7817939490870318 and parameters: {'n_estimators': 66, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:45,730] Trial 43 finished with value: 0.783406637345062 and parameters: {'n_estimators': 65, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:46,221] Trial 44 finished with value: 0.7557910169265626 and parameters: {'n_estimators': 58, 'max_depth': 6}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:46,658] Trial 45 finished with value: 0.7834199653471945 and parameters: {'n_estimators': 51, 'max_depth': 7}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:47,110] Trial 46 finished with value: 0.7687724910035986 and parameters: {'n_estimators': 52, 'max_depth': 8}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:48,407] Trial 47 finished with value: 0.7720378515260562 and parameters: {'n_estimators': 163, 'max_depth': 6}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:49,065] Trial 48 finished with value: 0.7704118352658936 and parameters: {'n_estimators': 76, 'max_depth': 9}. Best is trial 29 with value: 0.786658669865387.
# [I 2026-02-03 17:25:49,509] Trial 49 finished with value: 0.7736638677862189 and parameters: {'n_estimators': 50, 'max_depth': 8}. Best is trial 29 with value: 0.786658669865387.

# %%
study.best_params
# Out:
# {'n_estimators': 61, 'max_depth': 7}

# %%
study.best_trial.value
# Out:
# 0.786658669865387
